# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Here I imported everything I have used so far this year in case I will need to use it in my code.

# %%
train = pd.read_excel('Big Data Train Final.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('Big Data Final Test.xlsx', encoding = "iso-8859-1")
train.head()
# Out:
#    O Rk 1  O Pts/G 1  O TotPts 1   O Scrm Plys 1  O Yds/G 1  O Yds/P 1  \
# 0       1       27.0         378             935      434.0        6.5
# 1       2       33.7         472             925      409.7        6.2
# 2       5       28.1         394             865      384.4        6.2
# 3      15       24.2         339             831      352.9        5.9
# 4       9       27.0         378             870      372.6        6.0
#
#    O 1st/G 1  O 3rd Md 1  O 3rd Att 1  O 3rd Pct 1  ...  D 4th Md 2  \
# 0       24.4          85          175           49  ...          13
# 1       24.0          74          160           46  ...           3
# 2       22.1          76          166           46  ...           8
# 3       19.6          60          162           37  ...           7
# 4       20.9          75          170           44  ...           4
#
#    D 4th Att 2  D 4th Pct 2  D Pen 2  D Pen Yds 2            D ToP/G 2  \
# ...

# %% [markdown]
# On the first line I imported my training data, which I manually scraped from NFL.com. I spent a ton of time manually making a dataset until finding out how to manually scrape, so I was unfortunatley only able to get 15 rows but 76 columns. If I had more time I would be able to get hundreds of rows by manually scraping. I also imported my test data on the second line. This data was in a separate dataset and only had one row because I am only making one game prediction. This game hasn't happened yet so I can't check the accuracy. On the third line I printed the head of my training dataset to make sure it is working.

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result"]
features = ["O Rk 1", "O Pts/G 1", "O Yds/G 1", "D Rk 1", "D Pts/G 1", "D Yds/G 1", "TO 1", "O Rk 2", "O Pts/G 2", "O Yds/G 2", "D Rk 2", "D Pts/G 2", "D Yds/G 2", "TO 2"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %% [markdown]
# Here I made the variables I will need to make my prediction. My first attempt is commented out because it didn't work, but that's what I wrote. The first variable is all of the data from my dataset except for the result of the game that data is from. The second variable is just the result of that game. This way, the computer will be able to see how the training data relates to the result. I made a list that had all of the columns I want to use in my dataset.

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [13024]

# %% [markdown]
# Here I ran my prediction. I am making a prediction for the Cardinals at Seahawks game this upcoming weekend. The first number in this output is the team that won, then it is the number of points the winning team will put up, and finally it is the number of points the losing team will put up. This predicted that the Seahawks will beat the Cardinals 30 to 24.
